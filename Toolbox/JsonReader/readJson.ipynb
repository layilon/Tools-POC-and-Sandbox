# %%
import pandas as pd

# %%
from pandas import *

# %%
import urllib.request, json

with urllib.request.urlopen('[http://*]') as url:
    data = json.loads(url.read().decode())
    df = pd.DataFrame(json_normalize(data, 'historical')) #change accordingly
df.head()
# Out:
#          date       open       high  ...      vwap         label  changeOverTime
# 0  2019-03-12  45.000000  45.667500  ...  45.24583  March 12, 19         0.00506
# 1  2019-03-11  43.872501  44.779999  ...  44.44750  March 11, 19         0.01943
# 2  2019-03-08  42.580002  43.267502  ...  42.95667  March 08, 19         0.01521
# 3  2019-03-07  43.467499  43.610001  ...  43.24667  March 07, 19        -0.00788
# 4  2019-03-06  43.667500  43.872501  ...  43.66250  March 06, 19        -0.00086
#
# [5 rows x 13 columns]
